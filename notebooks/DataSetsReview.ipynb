# %%
import pandas as pd
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path, trunc=0):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
    if trunc > 0 and i > trunc: 
        break
  return pd.DataFrame.from_dict(df, orient='index')

data_path = '../../datasets/'
file_name = 'reviews_Movies_and_TV.json.gz'

# %%
df = getDF(data_path + file_name, 10)

# %%
df
# Out:
#         reviewerID        asin                     reviewerName   helpful  \
# 0   A3R5OBKS7OM2IR  0000143502               Rebecca L. Johnson    [0, 0]
# 1   A3R5OBKS7OM2IR  0000143529               Rebecca L. Johnson    [0, 0]
# 2    AH3QC2PC1VTGP  0000143561                  Great Home Cook    [2, 4]
# 3   A3LKP6WPMP9UKX  0000143588                  Anna V. Carroll    [9, 9]
# 4    AVIY68KEPQ5ZD  0000143588               Rebecca Millington    [1, 4]
# 5   A1CV1WROP5KTTW  0000589012  Alberta M. Worth "BertieMWorth"    [2, 2]
# 6    AP57WZ2X4G0AA  0000589012                Amy Arnett-German    [0, 1]
# 7   A3NMBJ2LCRCATT  0000589012                Carole J. Hopkins    [1, 1]
# 8    A5Y15SAOMX6XA  0000589012             Catherine E. Wetzler  [12, 16]
# 9   A3P671HJ32TCSF  0000589012                     Diane Buxton    [1, 1]
# 10  A3VCKTRD24BG7K  0000589012            Eric M. Bell "Deacon"    [1, 1]
#
#                                            reviewText  overall  \
# ...

# %%
df['reviewText'][0]
# Out:
# "This has some great tips as always and is helping me to complete my Good Eats collection.  I haven't tried any of the recipes yet, but I will soon.  Sometimes it's just lovely to let Alton entertain us."

# %%
file_name = 'meta_Movies_and_TV.json.gz'
df = getDF(data_path + file_name)

# %%
# Meta data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 208321 entries, 0 to 208320
# Data columns (total 9 columns):
# asin           208321 non-null object
# categories     208321 non-null object
# description    178086 non-null object
# title          107671 non-null object
# price          155623 non-null float64
# salesRank      204907 non-null object
# imUrl          207962 non-null object
# related        154859 non-null object
# brand          32730 non-null object
# dtypes: float64(1), object(8)
# memory usage: 15.9+ MB

# %%
df.head()
# Out:
#          asin               categories  \
# 0  0000143561  [[Movies & TV, Movies]]
# 1  0000589012  [[Movies & TV, Movies]]
# 2  0000695009  [[Movies & TV, Movies]]
# 3  000107461X  [[Movies & TV, Movies]]
# 4  0000143529  [[Movies & TV, Movies]]
#
#                                          description  \
# 0  3Pack DVD set - Italian Classics, Parties and ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Disc 1: Flour Power (Scones; Shortcakes; South...
#
#                                                title  price  \
# 0  Everyday Italian (with Giada de Laurentiis), V...  12.99
# 1  Why Don't They Just Quit? DVD Roundtable Discu...  15.95
# 2            Understanding Seizures and Epilepsy DVD    NaN
# 3                              Live in Houston [VHS]    NaN
# 4                  My Fair Pastry (Good Eats Vol. 9)  19.99
#
#                   salesRank  \
# ...

# %%
for i in range(4):
 print(df['title'].iloc[i])
# Out:
# Everyday Italian (with Giada de Laurentiis), Volume 1 (3 Pack): Italian Classics, Parties, Holidays
# Why Don't They Just Quit? DVD Roundtable Discussion: What Families and Friends need to Know About Addiction and Recovery
# Understanding Seizures and Epilepsy DVD
# Live in Houston [VHS]

# %%
for i in range(90041, 90044):
 print(df['title'].iloc[i])
 print(df['description'].iloc[i])
 print('   ')
# Out:
# Nightmare Street
# Nightmare Street on DVD.
#
# 08 Min Pilates
# nan
#
# Billy Blanks - Tae Bo - Billy's Favorite Moves
# This explosive new workout combines Billy s favorite Tae Bo and BootCamp moves into one fun energetic and calorie-blasting workout. From the basics up to the more advanced steps Billy has hand-picked these moves to give you the ultimate mental focus to burn fat and lose weight.System Requirements:Running Time 45 Mins.Format: DVD MOVIE Genre:&nbsp;HEALTH/FITNESS Rating:&nbsp;NR UPC:&nbsp;018713514486 Manufacturer No:&nbsp;51448

# %%
# Images links seem to work
for i in range(90000, 90003):
 print(df['imUrl'].iloc[i])
# Out:
# http://ecx.images-amazon.com/images/I/618JPX3KFGL._SY300_.jpg
# http://ecx.images-amazon.com/images/I/51JBX2FGQ7L._SY300_.jpg
# http://ecx.images-amazon.com/images/I/513JNqH18lL._SY300_.jpg

# %%
# Top title by number of ratings
df[df['asin'] == '1608838137']
# Out:
#             asin           categories  \
# 8373  1608838137  [[Movies & TV, TV]]
#
#                                             description  \
# 8373  The Great War is over and a long-awaited engag...
#
#                                             title  price  \
# 8373  Masterpiece Classic: Downton Abbey Season 3  24.99
#
#                    salesRank  \
# 8373  {'Movies & TV': 81965}
#
#                                                   imUrl  \
# 8373  http://ecx.images-amazon.com/images/I/51Mf88l1...
#
#                                                 related brand
# 8373  {'also_bought': ['B005Q1W10A', 'B00F1BFRA6', '...   NaN
